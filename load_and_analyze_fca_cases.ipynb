# %% [markdown]
# ### Notebook to load and analyze Federal Court of Appeal cases
#
# Sean Rehaag
#
# License: Creative Commons Attribution-NonCommercial 4.0 International [(CC BY-NC 4.0)](https://creativecommons.org/licenses/by-nc/4.0/). NOTE: Users must also comply with upstream [licensing](https://www.fca-caf.gc.ca/en/pages/important-notices) for the FCA source data, as well as requests on source urls not to allow indexing of the documents by search engines to protect privacy. As a result, users must not make the data available in formats or locations that can be indexed by search engines.
#
# Dataset & Code to be cited as:
#
#     Sean Rehaag, "Federal Court of Appeal Bulk Decisions Dataset" (2023), online: Refugee Law Laboratory <https://refugeelab.ca/bulk-data/fca/>.
#
# Notes:
#
# (1) Data Source: [Federal Court of Appeal](https://www.fca-caf.gc.ca).
#
# (2) Unofficial Data: The data are unofficial reproductions of materials on the Federal Court of Appeal website. Links to official versions are included in the dataset.
#
# (3) Non-Affiliation / Endorsement: The data has been collected and reproduced without any affiliation or endorsement from the Federal Court of Appeal
#
# (4) Non-Commerical Use: As indicated in the license, data may be used for non-commercial use (with attribution) only. For commercial use, see the Federal Court of Appeal website's [Terms of Use](https://www.fca-caf.gc.ca/en/pages/important-notices).
#
# (5) Accuracy: Data was collected and processed programmatically for the purposes of academic research. While we make best efforts to ensure accuracy, data gathering of this kind inevitably involves errors. As such the data should be viewed as preliminary information aimed to prompt further research and discussion, rather than as definitive information.
#
# (6) Limitation: Only includes cases with neutral citation, which began to be used in 2001
#
# (7) Delay: Decisions may take many months to be translated (sometimes over a year). As a result, in the most recent years, decisions may only be available in one language.
#
# ### Requirements:
#
#     pip install pandas
#
# ### If using parquet
#
#     pip install pyarrow
#
# ### if loading remotely (other than via Hugging Face)
#
#     pip install requests
#
# ### If loading remotely via Hugging Face
#
#     pip install datasets
#
#
# (Written on Python 3.9.12)
#
#
# (Written on Python 3.9.12)

# %% [markdown]
# ### Load Data
#
# Two Options: Local & Remote

# %%
# OPTION 1: Load Hugging Face dataset

from datasets import load_dataset
import pandas as pd

dataset = load_dataset("refugee-law-lab/canadian-legal-data", "FCA", split="train")

# convert to dataframe
df = pd.DataFrame(dataset)
df.head()
# Out:
# Downloading data:   0%|          | 0.00/132M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/14390 [00:00<?, ? examples/s]
#        citation citation2 dataset  year
# 0    2001 FCA 1               FCA  2001  \
# 1   2001 FCA 10               FCA  2001
# 2  2001 FCA 100               FCA  2001
# 3  2001 FCA 101               FCA  2001
# 4  2001 FCA 102               FCA  2001
#
#                                                 name language document_date
# 0  Bouvidard Ltée. c. Commission de l'assurance e...       en    2001-02-01  \
# 1  Mclean v. Canada (Minister of Citizenship and ...       en    2001-02-08
# 2  Mai v. Canada (Minister of Citizenship and Imm...       en    2001-04-02
# 3  Mitchell Verification Services Group Inc. v. C...       en    2001-04-03
# 4            Pontbriand v. Canada (Attorney General)       en    2001-04-03
#
#                                           source_url scraped_timestamp
# 0  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29  \
# 1  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 2  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 3  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 4  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
#
#                                      unofficial_text other
# 0  Bouvidard Ltée. c. Commission de l'assurance e...
# 1  Mclean v. Canada (Minister of Citizenship and ...
# 2  Mai v. Canada (Minister of Citizenship and Imm...
# 3  Mitchell Verification Services Group Inc. v. C...
# 4  Pontbriand v. Canada (Attorney General)\nCourt...

# %%
# OPTION 2: Load parquet data remotely from Huggingface without cloning repo
import pandas as pd
import requests
from io import BytesIO

url = 'https://huggingface.co/datasets/refugee-law-lab/canadian-legal-data/resolve/main/FCA/train.parquet'

# load data
results = requests.get(url)

# convert to dataframe
df = pd.read_parquet(BytesIO(results.content))
df.head()

# (if code fails, add engine='pyarrow' to read_parquet() function)
# Out:
#        citation citation2 dataset  year
# 0    2001 FCA 1               FCA  2001  \
# 1   2001 FCA 10               FCA  2001
# 2  2001 FCA 100               FCA  2001
# 3  2001 FCA 101               FCA  2001
# 4  2001 FCA 102               FCA  2001
#
#                                                 name language document_date
# 0  Bouvidard Ltée. c. Commission de l'assurance e...       en    2001-02-01  \
# 1  Mclean v. Canada (Minister of Citizenship and ...       en    2001-02-08
# 2  Mai v. Canada (Minister of Citizenship and Imm...       en    2001-04-02
# 3  Mitchell Verification Services Group Inc. v. C...       en    2001-04-03
# 4            Pontbriand v. Canada (Attorney General)       en    2001-04-03
#
#                                           source_url scraped_timestamp
# 0  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29  \
# 1  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 2  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 3  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 4  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
#
#                                      unofficial_text other
# 0  Bouvidard Ltée. c. Commission de l'assurance e...
# 1  Mclean v. Canada (Minister of Citizenship and ...
# 2  Mai v. Canada (Minister of Citizenship and Imm...
# 3  Mitchell Verification Services Group Inc. v. C...
# 4  Pontbriand v. Canada (Attorney General)\nCourt...

# %%
# OPTION 3: Load json data remotely from GitHub without cloning repo

import pandas as pd
import json
import requests

# Set variables
start_year = 2001  # First year of data sought (1877 +)
end_year = 2024  # Last year of data sought (2024 -)


base_ulr = 'https://raw.githubusercontent.com/Refugee-Law-Lab/fca_bulk_data/master/DATA/YEARLY/'

# load data
results = []
for year in range(start_year, end_year+1):
    url = base_ulr + f'{year}.json'
    results.extend(requests.get(url).json())

# convert to dataframe
df = pd.DataFrame(results)
df.head()
# Out:
#        citation citation2 dataset  year
# 0    2001 FCA 1               FCA  2001  \
# 1   2001 FCA 10               FCA  2001
# 2  2001 FCA 100               FCA  2001
# 3  2001 FCA 101               FCA  2001
# 4  2001 FCA 102               FCA  2001
#
#                                                 name language document_date
# 0  Bouvidard Ltée. c. Commission de l'assurance e...       en    2001-02-01  \
# 1  Mclean v. Canada (Minister of Citizenship and ...       en    2001-02-08
# 2  Mai v. Canada (Minister of Citizenship and Imm...       en    2001-04-02
# 3  Mitchell Verification Services Group Inc. v. C...       en    2001-04-03
# 4            Pontbriand v. Canada (Attorney General)       en    2001-04-03
#
#                                           source_url scraped_timestamp
# 0  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29  \
# 1  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 2  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 3  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 4  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
#
#                                      unofficial_text other
# 0  Bouvidard Ltée. c. Commission de l'assurance e...
# 1  Mclean v. Canada (Minister of Citizenship and ...
# 2  Mai v. Canada (Minister of Citizenship and Imm...
# 3  Mitchell Verification Services Group Inc. v. C...
# 4  Pontbriand v. Canada (Attorney General)\nCourt...

# %%
# OPTION 4: Load json data locally via cloned repo

# First, clone git repo to local machine
# Then run this code to load data

import pandas as pd
import json
import pathlib

# Set variables
start_year = 2001  # First year of data sought (1877 +)
end_year = 2024  # Last year of data sought (2024 -)


# Set path to data
data_path = pathlib.Path('DATA/YEARLY/')

# load data (all years, json files)
results = []
for year in range(start_year, end_year+1):
    with open(data_path / f'{year}.json') as f:
        results.extend(json.load(f))

# convert to dataframe
df = pd.DataFrame(results)
df.head()
# Out:
#        citation citation2 dataset  year
# 0    2001 FCA 1               FCA  2001  \
# 1   2001 FCA 10               FCA  2001
# 2  2001 FCA 100               FCA  2001
# 3  2001 FCA 101               FCA  2001
# 4  2001 FCA 102               FCA  2001
#
#                                                 name language document_date
# 0  Bouvidard Ltée. c. Commission de l'assurance e...       en    2001-02-01  \
# 1  Mclean v. Canada (Minister of Citizenship and ...       en    2001-02-08
# 2  Mai v. Canada (Minister of Citizenship and Imm...       en    2001-04-02
# 3  Mitchell Verification Services Group Inc. v. C...       en    2001-04-03
# 4            Pontbriand v. Canada (Attorney General)       en    2001-04-03
#
#                                           source_url scraped_timestamp
# 0  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29  \
# 1  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 2  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 3  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
# 4  https://decisions.fca-caf.gc.ca/fca-caf/decisi...        2022-08-29
#
#                                      unofficial_text other
# 0  Bouvidard Ltée. c. Commission de l'assurance e...
# 1  Mclean v. Canada (Minister of Citizenship and ...
# 2  Mai v. Canada (Minister of Citizenship and Imm...
# 3  Mitchell Verification Services Group Inc. v. C...
# 4  Pontbriand v. Canada (Attorney General)\nCourt...

# %% [markdown]
# ### Analyze Data

# %%
# View dataframe
df
# Out:
#            citation citation2 dataset  year
# 0        2001 FCA 1               FCA  2001  \
# 1       2001 FCA 10               FCA  2001
# 2      2001 FCA 100               FCA  2001
# 3      2001 FCA 101               FCA  2001
# 4      2001 FCA 102               FCA  2001
# ...             ...       ...     ...   ...
# 14385   2024 CAF 51               FCA  2024
# 14386   2024 CAF 52               FCA  2024
# 14387   2024 CAF 54               FCA  2024
# 14388   2024 CAF 58               FCA  2024
# 14389   2024 CAF 65               FCA  2024
#
#                                                     name language
# 0      Bouvidard Ltée. c. Commission de l'assurance e...       en  \
# 1      Mclean v. Canada (Minister of Citizenship and ...       en
# 2      Mai v. Canada (Minister of Citizenship and Imm...       en
# 3      Mitchell Verification Services Group Inc. v. C...       en
# 4                Pontbriand v. Canada (Attorney General)       en
# ...                                                  ...      ...
# 14385                             De Pellegrin c. Canada       fr
# 14386                Abdat c. Canada (Procureur général)       fr
# 14387  Bigdeli-Azari (Succession) c. Canada (Procureu...       fr
# 14388           Lalancette c. Canada (Procureur général)       fr
# 14389                   Essaï c. Banque Toronto Dominion       fr
#
#       document_date                                         source_url
# 0        2001-02-01  https://decisions.fca-caf.gc.ca/fca-caf/decisi...  \
# 1        2001-02-08  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 2        2001-04-02  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 3        2001-04-03  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 4        2001-04-03  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# ...             ...                                                ...
# 14385    2024-03-18  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 14386    2024-03-19  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 14387    2024-03-20  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 14388    2024-03-21  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 14389    2024-04-10  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
#
#       scraped_timestamp                                    unofficial_text
# 0            2022-08-29  Bouvidard Ltée. c. Commission de l'assurance e...  \
# 1            2022-08-29  Mclean v. Canada (Minister of Citizenship and ...
# 2            2022-08-29  Mai v. Canada (Minister of Citizenship and Imm...
# 3            2022-08-29  Mitchell Verification Services Group Inc. v. C...
# 4            2022-08-29  Pontbriand v. Canada (Attorney General)\nCourt...
# ...                 ...                                                ...
# 14385        2024-04-11  De Pellegrin c. Canada\nBase de données – Cour...
# 14386        2024-04-11  Abdat c. Canada (Procureur général)\nBase de d...
# 14387        2024-04-11  Bigdeli-Azari (Succession) c. Canada (Procureu...
# 14388        2024-04-11  Lalancette c. Canada (Procureur général)\nBase...
# 14389        2024-04-11  Essaï c. Banque Toronto Dominion\nBase de donn...
#
#       other
# 0
# 1
# 2
# 3
# 4
# ...     ...
# 14385
# 14386
# 14387
# 14388
# 14389
#
# [14390 rows x 11 columns]

# %%
# language counts
df['language'].value_counts()
# Out:
# language
# en    7262
# fr    7128
# Name: count, dtype: int64

# %%
# Yearly counts
year_counts = df.year.value_counts()
years_count = sorted(year_counts.index)
for year_count in years_count:
    print(f'{year_count}: {year_counts[year_count]}')
# Out:
# 2001: 790
# 2002: 1001
# 2003: 947
# 2004: 870
# 2005: 859
# 2006: 832
# 2007: 810
# 2008: 810
# 2009: 663
# 2010: 636
# 2011: 642
# 2012: 579
# 2013: 514
# 2014: 494
# 2015: 483
# 2016: 559
# 2017: 456
# 2018: 387
# 2019: 496
# 2020: 371
# 2021: 438
# 2022: 389
# 2023: 299
# 2024: 65
